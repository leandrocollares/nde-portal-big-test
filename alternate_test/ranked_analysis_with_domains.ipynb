# %%
import pandas as pd
from scipy.stats import wilcoxon
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
# Load domains

domains_df = pd.read_csv('./search_terms_domains.csv', sep=',')
domains_df
# Out:
#                      search term                   domain
# 0                      influenza       infectious disease
# 1                     long covid       infectious disease
# 2           malaria therapeutics       infectious disease
# 3                         asthma                  allergy
# 4    naegleria fowleri infection       infectious disease
# 5              zika microcephaly       infectious disease
# 6       allergen skin prick test                  allergy
# 7              allergy treatment                  allergy
# 8       sublingual immunotherapy                  allergy
# 9                           AIDS               immunology
# 10            immunotherapeutics               immunology
# 11               t-cell function               immunology
# 12             addison's disease               immunology
# 13                        cancer       general biomedical
# 14         myocardial infarction       general biomedical
# ...

# %%
# Load ranked analysis

ranked_df = pd.read_csv('./ranked_analysis_with_search_terms.csv', sep=',')
ranked_df
# Out:
#                              result id  original        c1        c2    c3  \
# 0                        S-EPMC6040727       1.5  1.333333  1.333333   1.2
# 1                  Mendeley_pzp26k9fy7       0.0  0.000000  0.000000   0.0
# 2    DRYAD_doi.org:10.5061:dryad.9r35r       0.0  0.000000  3.666667  11.0
# 3              veupathdb_DS_e8c4cf2187       0.0  0.000000  0.000000   0.0
# 4           Dataverse_10.5064_F6SF2T3N       0.0  0.000000  0.000000   0.0
# ..                                 ...       ...       ...       ...   ...
# 476                     ZENODO_5044544       0.0  0.000000  0.000000   0.0
# 477                     ZENODO_5008681       0.0  0.000000  0.000000   0.0
# 478                      S-EPMC6256666       1.7  1.700000  0.000000   0.0
# 479                  IMMPORT_SDY1515_2       0.0  0.000000  0.000000   0.0
# 480                   IMMPORT_SDY282_2       0.0  0.000000  0.000000   0.0
#
# ...

# %%
set(domains_df['search term']) - set(ranked_df['search term'])
# Out:
# set()

# %%
# Add domain info to ranked analysis data

ranked_df = ranked_df.merge(domains_df[['search term', 'domain']], 
                            how = 'left', on = 'search term').copy()
ranked_df
# Out:
#                              result id  original        c1        c2    c3  \
# 0                        S-EPMC6040727       1.5  1.333333  1.333333   1.2
# 1                  Mendeley_pzp26k9fy7       0.0  0.000000  0.000000   0.0
# 2    DRYAD_doi.org:10.5061:dryad.9r35r       0.0  0.000000  3.666667  11.0
# 3              veupathdb_DS_e8c4cf2187       0.0  0.000000  0.000000   0.0
# 4           Dataverse_10.5064_F6SF2T3N       0.0  0.000000  0.000000   0.0
# ..                                 ...       ...       ...       ...   ...
# 476                     ZENODO_5044544       0.0  0.000000  0.000000   0.0
# 477                     ZENODO_5008681       0.0  0.000000  0.000000   0.0
# 478                      S-EPMC6256666       1.7  1.700000  0.000000   0.0
# 479                  IMMPORT_SDY1515_2       0.0  0.000000  0.000000   0.0
# 480                   IMMPORT_SDY282_2       0.0  0.000000  0.000000   0.0
#
# ...

# %%
set(domains_df['search term']) - set(ranked_df['search term'])
# Out:
# set()

# %%
ranked_df.to_csv('../alternate_test/results/ranked_analysis_with_domains.csv', index = False)
