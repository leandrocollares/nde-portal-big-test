# %% [markdown]
# # Basic analysis - Lyssna data

# %% [markdown]
# ## 1. Data import

# %%
import pandas as pd
import numpy as np

pd.options.display.max_columns = 22
pd.options.display.max_rows = 150

# %%
# Load search term scopes

scopes_df = pd.read_csv('./search_term_scopes.csv', sep=',')
scopes_df
# Out:
#                      search term              scope
# 0                      influenza         very broad
# 1                     long covid              broad
# 2           malaria therapeutics      very specific
# 3                         asthma         very broad
# 4    naegleria fowleri infection      very specific
# 5              zika microcephaly  somewhat specific
# 6       allergen skin prick test  somewhat specific
# 7              allergy treatment              broad
# 8       sublingual immunotherapy      very specific
# 9                           AIDS         very broad
# 10            immunotherapeutics  somewhat specific
# 11               t-cell function              broad
# 12             addison's disease      very specific
# 13                        cancer         very broad
# 14         myocardial infarction              broad
# 15               dendritic cells         very broad
# 16                    mast cells              broad
# 17   rational cancer drug design  somewhat specific
# 18                  metabolomics         very broad
# 19                   pinealocyte      very specific
# 20  plasmacytoid dendritic cells  somewhat specific
# 21                          gwas              broad
# 22                 mycobacterium         very broad
# 23          tuberculin skin test  somewhat specific
# 24                           hiv         very broad

# %%
# Load Lyssna data

df = pd.read_csv('./all_rounds_data.csv', sep=',')
df
# Out:
#      round  test                   search term test type combo 1  ps 1  \
# 0        1     1                     influenza        M       c1     2
# 1        1     1                     influenza         L      c3     2
# 2        1     1                    long covid        M       c3     2
# 3        1     1                    long covid         L      c2     2
# 4        1     1          malaria therapeutics        M       c2     2
# 5        1     1          malaria therapeutics         L      c1     2
# 6        1     2                        asthma        M       c4     3
# 7        1     2                        asthma         L      c5     3
# 8        1     2   naegleria fowleri infection        M      c11     3
# 9        1     2   naegleria fowleri infection         L     c11     4
# 10       1     2             zika microcephaly        M       c1     3
# 11       1     2             zika microcephaly         L      c4     4
# 12       1     3      allergen skin prick test        M       c3     2
# 13       1     3      allergen skin prick test         L      c1     2
# 14       1     3             allergy treatment        M       c1     2
# 15       1     3             allergy treatment         L      c2     3
# 16       1     3      sublingual immunotherapy        M       c1     4
# 17       1     3      sublingual immunotherapy         L      c4     4
# 18       1     4                          AIDS        M       c4     2
# 19       1     4                          AIDS         L      c4     4
# 20       1     4            immunotherapeutics        M       c1     2
# 21       1     4            immunotherapeutics         L     c15     3
# 22       1     4               t-cell function        M       c3     2
# 23       1     4               t-cell function         L      c3     3
# 24       1     5             addison's disease        M       c2     4
# 25       1     5             addison's disease         L      c4     2
# 26       1     5                        cancer        M       c1     3
# 27       1     5                        cancer         L      c3     2
# 28       1     5         myocardial infarction        M       c4     2
# 29       1     5         myocardial infarction         L      c3     2
# 30       1     6               dendritic cells        M       c1     3
# 31       1     6               dendritic cells         L      c1     2
# 32       1     6                    mast cells        M       c1     4
# 33       1     6                    mast cells         L      c4     2
# 34       1     6   rational cancer drug design        M       c3     3
# 35       1     6   rational cancer drug design         L      c4     4
# 36       1     7                  metabolomics        M       c1     3
# 37       1     7                  metabolomics         L      c5     3
# 38       1     7                   pinealocyte        M      c10     2
# 39       1     7                   pinealocyte         L      c5     2
# 40       1     7  plasmacytoid dendritic cells        M       c4     3
# 41       1     7  plasmacytoid dendritic cells         L      c2     3
# 42       1     8                          gwas        M       c4     3
# 43       1     8                          gwas         L      c1     3
# 44       1     8                 mycobacterium        M       c1     3
# 45       1     8                 mycobacterium         L      c3     2
# 46       1     8          tuberculin skin test        M       c1     2
# 47       1     8          tuberculin skin test         L      c2     3
# 48       1     9                           hiv        M       c1     4
# 49       1     9                           hiv         L      c4     3
# 50       1     9                     influenza        M       c3     3
# 51       1     9                     influenza         L      c2     4
# 52       1     9                    long covid        M       c1     3
# 53       1     9                    long covid         L      c4     3
# 54       2     1                     influenza         M      c8     4
# 55       2     1                     influenza         L      c9     2
# 56       2     1                    long covid         M      c7     2
# 57       2     1                    long covid         L      c7     3
# 58       2     1          malaria therapeutics         M      c7     2
# 59       2     1          malaria therapeutics         L      c9     2
# 60       2     2             allergy treatment         M      c5     2
# 61       2     2             allergy treatment         L      c6     3
# 62       2     2                        asthma         M      c9     2
# 63       2     2                        asthma         L     c10     2
# 64       2     2             zika microcephaly         M      c8     3
# 65       2     2             zika microcephaly         L      c5     3
# 66       2     3                          AIDS         M      c6     2
# 67       2     3                          AIDS         L      c5     2
# 68       2     3      allergen skin prick test         M      c9     3
# 69       2     3      allergen skin prick test         L     c11     2
# 70       2     3      sublingual immunotherapy         M      c5     4
# 71       2     3      sublingual immunotherapy         L      c6     3
# 72       2     4             addison's disease         M      c7     4
# 73       2     4             addison's disease         L     c10     2
# 74       2     4                        cancer         M      c7     3
# 75       2     4                        cancer         L      c5     2
# 76       2     4               t-cell function         M      c8     5
# 77       2     4               t-cell function         L     c10     3
# 78       2     5               dendritic cells         M      c6     3
# 79       2     5               dendritic cells         L      c5     2
# 80       2     5         myocardial infarction         M      c6     3
# 81       2     5         myocardial infarction         L      c5     3
# 82       2     5   rational cancer drug design         M      c8     3
# 83       2     5   rational cancer drug design         L      c5     3
# 84       2     6                    mast cells         M      c6     4
# 85       2     6                    mast cells         L      c5     2
# 86       2     6                  metabolomics         M      c8     2
# 87       2     6                  metabolomics         L     c10     4
# 88       2     6  plasmacytoid dendritic cells         M      c7     3
# 89       2     6  plasmacytoid dendritic cells         L      c6     2
# 90       2     7                          gwas         M      c5     5
# 91       2     7                          gwas         L      c6     4
# 92       2     7                 mycobacterium         M      c8     2
# 93       2     7                 mycobacterium         L      c5     2
# 94       2     7          tuberculin skin test         M      c7     2
# 95       2     7          tuberculin skin test         L      c5     3
# 96       2     8                           hiv         M      c8     2
# 97       2     8                           hiv         L      c8     4
# 98       2     8                     influenza         M      c8     2
# 99       2     8                     influenza         L      c9     3
# 100      2     8                    long covid         M      c8     3
# 101      2     8                    long covid         L      c6     2
#
#      pct ps 1  time 1 combo 2  ps 2  pct ps 2  time 2 combo 3  ps 3  pct ps 3  \
# 0          40      34      c3     1        20   156.0      c4     1        20
# 1          40      57      c4     2        40    34.0      c1     1        20
# 2          40     107      c4     2        40   166.0      c2     1        20
# 3          40       9      c3     1        20    77.0      c4     1        20
# 4          40      31      c4     1        20    27.0      c1     1        20
# 5          40      27      c4     1        20    10.0      c2     1        20
# 6          60      56      c5     1        20    52.0      c1     1        20
# 7          60      19      c1     2        40     9.0      c4     0         0
# 8          60      23      c1     2        40    72.0     c10     0         0
# 9          80      14     c10     1        20    98.0     c14     0         0
# 10         60      40      c2     1        20    36.0      c3     1        20
# 11         80       8      c2     1        20    28.0      c1     0         0
# 12         40     121      c4     1        20    39.0      c1     1        20
# 13         40      37      c4     1        20    12.0      c2     1        20
# 14         40      51      c3     1        20    52.0      c4     1        20
# 15         60      25      c3     1        20    23.0      c1     1        20
# 16         80      40      c4     1        20    26.0      c2     0         0
# 17         80      17      c3     1        20    23.0      c1     0         0
# 18         40      88      c1     2        40   127.0      c2     1        20
# 19         80      59      c1     1        20     6.0      c3     0         0
# 20         40      20      c2     2        40    97.0     c15     1        20
# 21         60      11      c1     2        40    16.0      c2     0         0
# 22         40     117      c4     2        40    45.0      c1     1        20
# 23         60      12      c2     1        20    10.0      c4     1        20
# 24         80     118      c1     1        20    45.0      c3     0         0
# 25         40      26      c1     1        20    11.0      c2     1        20
# 26         60      29      c4     1        20    24.0      c2     1        20
# 27         40      16      c4     2        40    14.0      c2     1        20
# 28         40      69      c1     2        40    40.0      c3     1        20
# 29         40      12      c4     2        40     7.0      c2     1        20
# 30         60     167      c4     1        20    66.0      c3     1        20
# 31         40      51      c3     1        20    14.0      c4     1        20
# 32         80      59      c2     1        20    39.0      c3     0         0
# 33         40      41      c1     1        20     7.0      c2     1        20
# 34         60      52      c1     1        20    24.0      c4     1        20
# 35         80      19      c2     1        20    42.0      c3     0         0
# 36         60      27      c5     2        40   105.0      c3     0         0
# 37         60       8      c3     1        20    17.0      c4     1        20
# 38         40      31      c5     2        40     5.0      c1     1        20
# 39         40       6      c1     2        40    30.0     c10     1        20
# 40         60      15      c2     2        40    22.0      c1     0         0
# 41         60       7      c3     1        20    16.0      c4     1        20
# 42         60      36      c2     1        20    17.0      c3     1        20
# 43         60      22      c2     1        20    10.0      c3     1        20
# 44         60      28      c2     2        40    51.0      c3     0         0
# 45         40      10      c4     2        40    27.0      c1     1        20
# 46         40      23      c4     2        40    45.0      c2     1        20
# 47         60      15      c3     1        20     4.0      c1     1        20
# 48         80      49      c3     1        20    59.0      c4     0         0
# 49         60      10      c1     1        20    10.0      c3     1        20
# 50         60      19      c1     2        40    16.0      c4     0         0
# 51         80      10      c4     1        20    13.0      c3     0         0
# 52         60      22      c4     1        20     4.0      c2     1        20
# 53         60      12      c1     1        20    16.0      c2     1        20
# 54         80      63      c7     1        20    52.0      c9     0         0
# 55         40      47      c5     2        40    14.0      c7     1        20
# 56         40      19      c8     2        40    39.0      c6     1        20
# 57         60      21      c5     2        40    17.0      c6     0         0
# 58         40      35      c5     1        20    88.0      c6     1        20
# 59         40      23      c5     2        40     9.0      c7     1        20
# 60         40      92      c6     2        40    57.0      c8     1        20
# 61         60      21      c8     1        20    37.0      c5     1        20
# 62         40      30      c8     2        40    17.0     c10     1        20
# 63         40       9      c8     1        20    16.0      c9     1        20
# 64         60      21      c9     1        20     2.0      c7     1        20
# 65         60       9      c7     2        40    10.0      c8     0         0
# 66         40     153      c8     2        40    90.0      c7     1        20
# 67         40      38      c7     1        20    64.0      c8     1        20
# 68         60      30      c8     1        20    98.0     c10     1        20
# 69         40      70      c8     2        40    17.0     c10     1        20
# 70         80      62      c6     1        20    17.0      c7     0         0
# 71         60      28      c5     1        20    34.0      c8     1        20
# 72         80      83      c8     1        20    52.0     c10     0         0
# 73         40       5      c5     2        40    18.0      c7     1        20
# 74         60      71      c6     2        40    31.0      c8     0         0
# 75         40      13      c7     1        20    26.0      c8     1        20
# 76        100      42      c5     0         0     NaN      c9     0         0
# 77         60      16      c8     1        20    20.0      c9     1        20
# 78         60      42      c5     2        40    33.0      c7     0         0
# 79         40      10      c6     2        40    15.0      c8     1        20
# 80         60      54      c5     1        20    14.0      c8     1        20
# 81         60      28      c7     2        40     4.0      c6     0         0
# 82         60      40      c9     2        40    83.0     c10     0         0
# 83         60      17      c8     1        20     9.0     c10     1        20
# 84         80      80      c5     1        20    24.0      c7     0         0
# 85         40      44      c7     2        40    16.0      c8     1        20
# 86         40      44      c9     2        40    25.0     c13     1        20
# 87         80      17     c13     1        20    27.0      c9     0         0
# 88         60      31      c8     2        40    78.0      c5     0         0
# 89         40      21      c7     2        40    49.0      c8     1        20
# 90        100      68      c8     0         0     NaN      c6     0         0
# 91         80      20      c5     1        20    34.0      c7     0         0
# 92         40      34      c6     2        40    44.0      c7     1        20
# 93         40      23      c6     2        40     8.0      c7     1        20
# 94         40      33      c5     1        20   222.0      c8     1        20
# 95         60      37      c7     1        20    11.0      c9     1        20
# 96         40     136      c5     2        40    23.0      c7     1        20
# 97         80      28      c5     1        20     7.0      c6     0         0
# 98         40      61      c9     2        40    25.0      c5     1        20
# 99         60      26      c8     2        40    55.0      c5     0         0
# 100        60      28      c6     1        20    87.0      c7     1        20
# 101        40      35      c7     2        40    44.0      c5     1        20
#
#      time 3 combo 4  ps 4  pct ps 4  time 4
# 0     105.0      c2   1.0      20.0    71.0
# 1      23.0      c2   0.0       0.0     NaN
# 2      18.0      c1   0.0       0.0     NaN
# 3      95.0      c1   1.0      20.0    16.0
# 4      50.0      c3   1.0      20.0    76.0
# 5       4.0      c3   1.0      20.0    31.0
# 6      24.0      c2   0.0       0.0     NaN
# 7       NaN      c2   0.0       0.0     NaN
# 8       NaN     c14   0.0       0.0     NaN
# 9       NaN      c1   0.0       0.0     NaN
# 10     35.0      c4   0.0       0.0     NaN
# 11      NaN      c3   0.0       0.0     NaN
# 12     52.0      c2   1.0      20.0    71.0
# 13     49.0      c3   1.0      20.0    22.0
# 14     25.0      c2   1.0      20.0    31.0
# 15      4.0      c4   0.0       0.0     NaN
# 16      NaN      c3   0.0       0.0     NaN
# 17      NaN      c2   0.0       0.0     NaN
# 18     14.0      c3   0.0       0.0     NaN
# 19      NaN      c2   0.0       0.0     NaN
# 20     58.0     NaN   NaN       NaN     NaN
# 21      NaN     NaN   NaN       NaN     NaN
# 22     16.0      c2   0.0       0.0     NaN
# 23    130.0      c1   0.0       0.0     NaN
# 24      NaN      c4   0.0       0.0     NaN
# 25     35.0      c3   1.0      20.0    34.0
# 26     46.0      c3   0.0       0.0     NaN
# 27     29.0      c1   0.0       0.0     NaN
# 28     32.0      c2   0.0       0.0     NaN
# 29     33.0      c1   0.0       0.0     NaN
# 30     45.0      c2   0.0       0.0     NaN
# 31      8.0      c2   1.0      20.0     6.0
# 32      NaN      c4   0.0       0.0     NaN
# 33     17.0      c3   1.0      20.0     5.0
# 34     58.0      c2   0.0       0.0     NaN
# 35      NaN      c1   0.0       0.0     NaN
# 36      NaN      c4   0.0       0.0     NaN
# 37      9.0      c1   0.0       0.0     NaN
# 38      7.0      c4   0.0       0.0     NaN
# 39      6.0      c4   0.0       0.0     NaN
# 40      NaN      c3   0.0       0.0     NaN
# 41      7.0      c1   0.0       0.0     NaN
# 42      9.0      c1   0.0       0.0     NaN
# 43      6.0      c4   0.0       0.0     NaN
# 44      NaN      c4   0.0       0.0     NaN
# 45      3.0      c2   0.0       0.0     NaN
# 46     18.0      c3   0.0       0.0     NaN
# 47      5.0      c4   0.0       0.0     NaN
# 48      NaN      c2   0.0       0.0     NaN
# 49     45.0      c2   0.0       0.0     NaN
# 50      NaN      c2   0.0       0.0     NaN
# 51      NaN      c1   0.0       0.0     NaN
# 52     20.0      c3   0.0       0.0     NaN
# 53     13.0      c3   0.0       0.0     NaN
# 54      NaN      c5   0.0       0.0     NaN
# 55     13.0      c8   0.0       0.0     NaN
# 56     56.0      c5   0.0       0.0     NaN
# 57      NaN      c8   0.0       0.0     NaN
# 58    106.0      c9   1.0      20.0    28.0
# 59     28.0      c6   0.0       0.0     NaN
# 60     26.0      c7   0.0       0.0     NaN
# 61     15.0      c7   0.0       0.0     NaN
# 62     39.0      c7   0.0       0.0     NaN
# 63     13.0      c7   1.0      20.0    46.0
# 64     16.0      c5   0.0       0.0     NaN
# 65      NaN      c9   0.0       0.0     NaN
# 66    124.0      c5   0.0       0.0     NaN
# 67     44.0      c6   1.0      20.0    21.0
# 68    235.0     c11   0.0       0.0     NaN
# 69     52.0      c9   0.0       0.0     NaN
# 70      NaN      c8   0.0       0.0     NaN
# 71      3.0      c7   0.0       0.0     NaN
# 72      NaN      c5   0.0       0.0     NaN
# 73     60.0      c8   0.0       0.0     NaN
# 74      NaN      c5   0.0       0.0     NaN
# 75      5.0      c6   1.0      20.0    11.0
# 76      NaN     c10   0.0       0.0     NaN
# 77     11.0      c5   0.0       0.0     NaN
# 78      NaN      c8   0.0       0.0     NaN
# 79     19.0      c7   0.0       0.0     NaN
# 80    107.0      c7   0.0       0.0     NaN
# 81      NaN      c8   0.0       0.0     NaN
# 82      NaN      c5   0.0       0.0     NaN
# 83     39.0      c9   0.0       0.0     NaN
# 84      NaN      c8   0.0       0.0     NaN
# 85     20.0      c6   0.0       0.0     NaN
# 86     74.0     c10   0.0       0.0     NaN
# 87      NaN      c8   0.0       0.0     NaN
# 88      NaN      c6   0.0       0.0     NaN
# 89     13.0      c5   0.0       0.0     NaN
# 90      NaN      c7   0.0       0.0     NaN
# 91      NaN      c8   0.0       0.0     NaN
# 92    179.0      c5   0.0       0.0     NaN
# 93     37.0      c8   0.0       0.0     NaN
# 94     20.0      c9   1.0      20.0    79.0
# 95     11.0      c8   0.0       0.0     NaN
# 96     82.0      c6   0.0       0.0     NaN
# 97      NaN      c7   0.0       0.0     NaN
# 98     23.0      c7   0.0       0.0     NaN
# 99      NaN      c7   0.0       0.0     NaN
# 100    44.0      c5   0.0       0.0     NaN
# 101    44.0      c8   0.0       0.0     NaN

# %%
# Columns

# round: Lyssna round number
# test: test number
# search term
# test type: M -> participants decide which set of results is the most relevant one 
#            L -> participants decide which set of results is the least relevant one
# combo x: combination presented to participants
# ps x: number of participants that selected the combination under combo x as the most/least relevant
# pct ps x: percentage of participants that selected the combination under combo x as the most/least relevant
# time x: average time spent by participants to select the combination under combo x as the most/least relevant

# %%
# Unique search terms

df['search term'].unique()
# Out:
# array(['influenza', 'long covid', 'malaria therapeutics', 'asthma',
#        'naegleria fowleri infection', 'zika microcephaly',
#        'allergen skin prick test', 'allergy treatment',
#        'sublingual immunotherapy', 'AIDS', 'immunotherapeutics',
#        't-cell function', "addison's disease", 'cancer',
#        'myocardial infarction', 'dendritic cells', 'mast cells',
#        'rational cancer drug design', 'metabolomics', 'pinealocyte',
#        'plasmacytoid dendritic cells', 'gwas', 'mycobacterium',
#        'tuberculin skin test', 'hiv'], dtype=object)

# %% [markdown]
# ## 2. Data wrangling

# %%
# Add search result scope info to Lysnna dataframe and reorder columns

df = df.merge(scopes_df[['search term', 'scope']], how = 'left', on = 'search term')
df = df.reindex(columns = ['round', 'test', 'search term', 'scope', 'test type', 'combo 1', 'ps 1',
                           'pct ps 1', 'time 1', 'combo 2', 'ps 2', 'pct ps 2', 'time 2',
                           'combo 3', 'ps 3', 'pct ps 3', 'time 3', 'combo 4', 'ps 4', 'pct ps 4', 'time 4'])
df
# Out:
#      round  test                   search term              scope test type  \
# 0        1     1                     influenza         very broad        M
# 1        1     1                     influenza         very broad         L
# 2        1     1                    long covid              broad        M
# 3        1     1                    long covid              broad         L
# 4        1     1          malaria therapeutics      very specific        M
# 5        1     1          malaria therapeutics      very specific         L
# 6        1     2                        asthma         very broad        M
# 7        1     2                        asthma         very broad         L
# 8        1     2   naegleria fowleri infection      very specific        M
# 9        1     2   naegleria fowleri infection      very specific         L
# 10       1     2             zika microcephaly  somewhat specific        M
# 11       1     2             zika microcephaly  somewhat specific         L
# 12       1     3      allergen skin prick test  somewhat specific        M
# 13       1     3      allergen skin prick test  somewhat specific         L
# 14       1     3             allergy treatment              broad        M
# 15       1     3             allergy treatment              broad         L
# 16       1     3      sublingual immunotherapy      very specific        M
# 17       1     3      sublingual immunotherapy      very specific         L
# 18       1     4                          AIDS         very broad        M
# 19       1     4                          AIDS         very broad         L
# 20       1     4            immunotherapeutics  somewhat specific        M
# 21       1     4            immunotherapeutics  somewhat specific         L
# 22       1     4               t-cell function              broad        M
# 23       1     4               t-cell function              broad         L
# 24       1     5             addison's disease      very specific        M
# 25       1     5             addison's disease      very specific         L
# 26       1     5                        cancer         very broad        M
# 27       1     5                        cancer         very broad         L
# 28       1     5         myocardial infarction              broad        M
# 29       1     5         myocardial infarction              broad         L
# 30       1     6               dendritic cells         very broad        M
# 31       1     6               dendritic cells         very broad         L
# 32       1     6                    mast cells              broad        M
# 33       1     6                    mast cells              broad         L
# 34       1     6   rational cancer drug design  somewhat specific        M
# 35       1     6   rational cancer drug design  somewhat specific         L
# 36       1     7                  metabolomics         very broad        M
# 37       1     7                  metabolomics         very broad         L
# 38       1     7                   pinealocyte      very specific        M
# 39       1     7                   pinealocyte      very specific         L
# 40       1     7  plasmacytoid dendritic cells  somewhat specific        M
# 41       1     7  plasmacytoid dendritic cells  somewhat specific         L
# 42       1     8                          gwas              broad        M
# 43       1     8                          gwas              broad         L
# 44       1     8                 mycobacterium         very broad        M
# 45       1     8                 mycobacterium         very broad         L
# 46       1     8          tuberculin skin test  somewhat specific        M
# 47       1     8          tuberculin skin test  somewhat specific         L
# 48       1     9                           hiv         very broad        M
# 49       1     9                           hiv         very broad         L
# 50       1     9                     influenza         very broad        M
# 51       1     9                     influenza         very broad         L
# 52       1     9                    long covid              broad        M
# 53       1     9                    long covid              broad         L
# 54       2     1                     influenza         very broad         M
# 55       2     1                     influenza         very broad         L
# 56       2     1                    long covid              broad         M
# 57       2     1                    long covid              broad         L
# 58       2     1          malaria therapeutics      very specific         M
# 59       2     1          malaria therapeutics      very specific         L
# 60       2     2             allergy treatment              broad         M
# 61       2     2             allergy treatment              broad         L
# 62       2     2                        asthma         very broad         M
# 63       2     2                        asthma         very broad         L
# 64       2     2             zika microcephaly  somewhat specific         M
# 65       2     2             zika microcephaly  somewhat specific         L
# 66       2     3                          AIDS         very broad         M
# 67       2     3                          AIDS         very broad         L
# 68       2     3      allergen skin prick test  somewhat specific         M
# 69       2     3      allergen skin prick test  somewhat specific         L
# 70       2     3      sublingual immunotherapy      very specific         M
# 71       2     3      sublingual immunotherapy      very specific         L
# 72       2     4             addison's disease      very specific         M
# 73       2     4             addison's disease      very specific         L
# 74       2     4                        cancer         very broad         M
# 75       2     4                        cancer         very broad         L
# 76       2     4               t-cell function              broad         M
# 77       2     4               t-cell function              broad         L
# 78       2     5               dendritic cells         very broad         M
# 79       2     5               dendritic cells         very broad         L
# 80       2     5         myocardial infarction              broad         M
# 81       2     5         myocardial infarction              broad         L
# 82       2     5   rational cancer drug design  somewhat specific         M
# 83       2     5   rational cancer drug design  somewhat specific         L
# 84       2     6                    mast cells              broad         M
# 85       2     6                    mast cells              broad         L
# 86       2     6                  metabolomics         very broad         M
# 87       2     6                  metabolomics         very broad         L
# 88       2     6  plasmacytoid dendritic cells  somewhat specific         M
# 89       2     6  plasmacytoid dendritic cells  somewhat specific         L
# 90       2     7                          gwas              broad         M
# 91       2     7                          gwas              broad         L
# 92       2     7                 mycobacterium         very broad         M
# 93       2     7                 mycobacterium         very broad         L
# 94       2     7          tuberculin skin test  somewhat specific         M
# 95       2     7          tuberculin skin test  somewhat specific         L
# 96       2     8                           hiv         very broad         M
# 97       2     8                           hiv         very broad         L
# 98       2     8                     influenza         very broad         M
# 99       2     8                     influenza         very broad         L
# 100      2     8                    long covid              broad         M
# 101      2     8                    long covid              broad         L
#
#     combo 1  ps 1  pct ps 1  time 1 combo 2  ps 2  pct ps 2  time 2 combo 3  \
# 0        c1     2        40      34      c3     1        20   156.0      c4
# 1        c3     2        40      57      c4     2        40    34.0      c1
# 2        c3     2        40     107      c4     2        40   166.0      c2
# 3        c2     2        40       9      c3     1        20    77.0      c4
# 4        c2     2        40      31      c4     1        20    27.0      c1
# 5        c1     2        40      27      c4     1        20    10.0      c2
# 6        c4     3        60      56      c5     1        20    52.0      c1
# 7        c5     3        60      19      c1     2        40     9.0      c4
# 8       c11     3        60      23      c1     2        40    72.0     c10
# 9       c11     4        80      14     c10     1        20    98.0     c14
# 10       c1     3        60      40      c2     1        20    36.0      c3
# 11       c4     4        80       8      c2     1        20    28.0      c1
# 12       c3     2        40     121      c4     1        20    39.0      c1
# 13       c1     2        40      37      c4     1        20    12.0      c2
# 14       c1     2        40      51      c3     1        20    52.0      c4
# 15       c2     3        60      25      c3     1        20    23.0      c1
# 16       c1     4        80      40      c4     1        20    26.0      c2
# 17       c4     4        80      17      c3     1        20    23.0      c1
# 18       c4     2        40      88      c1     2        40   127.0      c2
# 19       c4     4        80      59      c1     1        20     6.0      c3
# 20       c1     2        40      20      c2     2        40    97.0     c15
# 21      c15     3        60      11      c1     2        40    16.0      c2
# 22       c3     2        40     117      c4     2        40    45.0      c1
# 23       c3     3        60      12      c2     1        20    10.0      c4
# 24       c2     4        80     118      c1     1        20    45.0      c3
# 25       c4     2        40      26      c1     1        20    11.0      c2
# 26       c1     3        60      29      c4     1        20    24.0      c2
# 27       c3     2        40      16      c4     2        40    14.0      c2
# 28       c4     2        40      69      c1     2        40    40.0      c3
# 29       c3     2        40      12      c4     2        40     7.0      c2
# 30       c1     3        60     167      c4     1        20    66.0      c3
# 31       c1     2        40      51      c3     1        20    14.0      c4
# 32       c1     4        80      59      c2     1        20    39.0      c3
# 33       c4     2        40      41      c1     1        20     7.0      c2
# 34       c3     3        60      52      c1     1        20    24.0      c4
# 35       c4     4        80      19      c2     1        20    42.0      c3
# 36       c1     3        60      27      c5     2        40   105.0      c3
# 37       c5     3        60       8      c3     1        20    17.0      c4
# 38      c10     2        40      31      c5     2        40     5.0      c1
# 39       c5     2        40       6      c1     2        40    30.0     c10
# 40       c4     3        60      15      c2     2        40    22.0      c1
# 41       c2     3        60       7      c3     1        20    16.0      c4
# 42       c4     3        60      36      c2     1        20    17.0      c3
# 43       c1     3        60      22      c2     1        20    10.0      c3
# 44       c1     3        60      28      c2     2        40    51.0      c3
# 45       c3     2        40      10      c4     2        40    27.0      c1
# 46       c1     2        40      23      c4     2        40    45.0      c2
# 47       c2     3        60      15      c3     1        20     4.0      c1
# 48       c1     4        80      49      c3     1        20    59.0      c4
# 49       c4     3        60      10      c1     1        20    10.0      c3
# 50       c3     3        60      19      c1     2        40    16.0      c4
# 51       c2     4        80      10      c4     1        20    13.0      c3
# 52       c1     3        60      22      c4     1        20     4.0      c2
# 53       c4     3        60      12      c1     1        20    16.0      c2
# 54       c8     4        80      63      c7     1        20    52.0      c9
# 55       c9     2        40      47      c5     2        40    14.0      c7
# 56       c7     2        40      19      c8     2        40    39.0      c6
# 57       c7     3        60      21      c5     2        40    17.0      c6
# 58       c7     2        40      35      c5     1        20    88.0      c6
# 59       c9     2        40      23      c5     2        40     9.0      c7
# 60       c5     2        40      92      c6     2        40    57.0      c8
# 61       c6     3        60      21      c8     1        20    37.0      c5
# 62       c9     2        40      30      c8     2        40    17.0     c10
# 63      c10     2        40       9      c8     1        20    16.0      c9
# 64       c8     3        60      21      c9     1        20     2.0      c7
# 65       c5     3        60       9      c7     2        40    10.0      c8
# 66       c6     2        40     153      c8     2        40    90.0      c7
# 67       c5     2        40      38      c7     1        20    64.0      c8
# 68       c9     3        60      30      c8     1        20    98.0     c10
# 69      c11     2        40      70      c8     2        40    17.0     c10
# 70       c5     4        80      62      c6     1        20    17.0      c7
# 71       c6     3        60      28      c5     1        20    34.0      c8
# 72       c7     4        80      83      c8     1        20    52.0     c10
# 73      c10     2        40       5      c5     2        40    18.0      c7
# 74       c7     3        60      71      c6     2        40    31.0      c8
# 75       c5     2        40      13      c7     1        20    26.0      c8
# 76       c8     5       100      42      c5     0         0     NaN      c9
# 77      c10     3        60      16      c8     1        20    20.0      c9
# 78       c6     3        60      42      c5     2        40    33.0      c7
# 79       c5     2        40      10      c6     2        40    15.0      c8
# 80       c6     3        60      54      c5     1        20    14.0      c8
# 81       c5     3        60      28      c7     2        40     4.0      c6
# 82       c8     3        60      40      c9     2        40    83.0     c10
# 83       c5     3        60      17      c8     1        20     9.0     c10
# 84       c6     4        80      80      c5     1        20    24.0      c7
# 85       c5     2        40      44      c7     2        40    16.0      c8
# 86       c8     2        40      44      c9     2        40    25.0     c13
# 87      c10     4        80      17     c13     1        20    27.0      c9
# 88       c7     3        60      31      c8     2        40    78.0      c5
# 89       c6     2        40      21      c7     2        40    49.0      c8
# 90       c5     5       100      68      c8     0         0     NaN      c6
# 91       c6     4        80      20      c5     1        20    34.0      c7
# 92       c8     2        40      34      c6     2        40    44.0      c7
# 93       c5     2        40      23      c6     2        40     8.0      c7
# 94       c7     2        40      33      c5     1        20   222.0      c8
# 95       c5     3        60      37      c7     1        20    11.0      c9
# 96       c8     2        40     136      c5     2        40    23.0      c7
# 97       c8     4        80      28      c5     1        20     7.0      c6
# 98       c8     2        40      61      c9     2        40    25.0      c5
# 99       c9     3        60      26      c8     2        40    55.0      c5
# 100      c8     3        60      28      c6     1        20    87.0      c7
# 101      c6     2        40      35      c7     2        40    44.0      c5
#
#      ps 3  pct ps 3  time 3 combo 4  ps 4  pct ps 4  time 4
# 0       1        20   105.0      c2   1.0      20.0    71.0
# 1       1        20    23.0      c2   0.0       0.0     NaN
# 2       1        20    18.0      c1   0.0       0.0     NaN
# 3       1        20    95.0      c1   1.0      20.0    16.0
# 4       1        20    50.0      c3   1.0      20.0    76.0
# 5       1        20     4.0      c3   1.0      20.0    31.0
# 6       1        20    24.0      c2   0.0       0.0     NaN
# 7       0         0     NaN      c2   0.0       0.0     NaN
# 8       0         0     NaN     c14   0.0       0.0     NaN
# 9       0         0     NaN      c1   0.0       0.0     NaN
# 10      1        20    35.0      c4   0.0       0.0     NaN
# 11      0         0     NaN      c3   0.0       0.0     NaN
# 12      1        20    52.0      c2   1.0      20.0    71.0
# 13      1        20    49.0      c3   1.0      20.0    22.0
# 14      1        20    25.0      c2   1.0      20.0    31.0
# 15      1        20     4.0      c4   0.0       0.0     NaN
# 16      0         0     NaN      c3   0.0       0.0     NaN
# 17      0         0     NaN      c2   0.0       0.0     NaN
# 18      1        20    14.0      c3   0.0       0.0     NaN
# 19      0         0     NaN      c2   0.0       0.0     NaN
# 20      1        20    58.0     NaN   NaN       NaN     NaN
# 21      0         0     NaN     NaN   NaN       NaN     NaN
# 22      1        20    16.0      c2   0.0       0.0     NaN
# 23      1        20   130.0      c1   0.0       0.0     NaN
# 24      0         0     NaN      c4   0.0       0.0     NaN
# 25      1        20    35.0      c3   1.0      20.0    34.0
# 26      1        20    46.0      c3   0.0       0.0     NaN
# 27      1        20    29.0      c1   0.0       0.0     NaN
# 28      1        20    32.0      c2   0.0       0.0     NaN
# 29      1        20    33.0      c1   0.0       0.0     NaN
# 30      1        20    45.0      c2   0.0       0.0     NaN
# 31      1        20     8.0      c2   1.0      20.0     6.0
# 32      0         0     NaN      c4   0.0       0.0     NaN
# 33      1        20    17.0      c3   1.0      20.0     5.0
# 34      1        20    58.0      c2   0.0       0.0     NaN
# 35      0         0     NaN      c1   0.0       0.0     NaN
# 36      0         0     NaN      c4   0.0       0.0     NaN
# 37      1        20     9.0      c1   0.0       0.0     NaN
# 38      1        20     7.0      c4   0.0       0.0     NaN
# 39      1        20     6.0      c4   0.0       0.0     NaN
# 40      0         0     NaN      c3   0.0       0.0     NaN
# 41      1        20     7.0      c1   0.0       0.0     NaN
# 42      1        20     9.0      c1   0.0       0.0     NaN
# 43      1        20     6.0      c4   0.0       0.0     NaN
# 44      0         0     NaN      c4   0.0       0.0     NaN
# 45      1        20     3.0      c2   0.0       0.0     NaN
# 46      1        20    18.0      c3   0.0       0.0     NaN
# 47      1        20     5.0      c4   0.0       0.0     NaN
# 48      0         0     NaN      c2   0.0       0.0     NaN
# 49      1        20    45.0      c2   0.0       0.0     NaN
# 50      0         0     NaN      c2   0.0       0.0     NaN
# 51      0         0     NaN      c1   0.0       0.0     NaN
# 52      1        20    20.0      c3   0.0       0.0     NaN
# 53      1        20    13.0      c3   0.0       0.0     NaN
# 54      0         0     NaN      c5   0.0       0.0     NaN
# 55      1        20    13.0      c8   0.0       0.0     NaN
# 56      1        20    56.0      c5   0.0       0.0     NaN
# 57      0         0     NaN      c8   0.0       0.0     NaN
# 58      1        20   106.0      c9   1.0      20.0    28.0
# 59      1        20    28.0      c6   0.0       0.0     NaN
# 60      1        20    26.0      c7   0.0       0.0     NaN
# 61      1        20    15.0      c7   0.0       0.0     NaN
# 62      1        20    39.0      c7   0.0       0.0     NaN
# 63      1        20    13.0      c7   1.0      20.0    46.0
# 64      1        20    16.0      c5   0.0       0.0     NaN
# 65      0         0     NaN      c9   0.0       0.0     NaN
# 66      1        20   124.0      c5   0.0       0.0     NaN
# 67      1        20    44.0      c6   1.0      20.0    21.0
# 68      1        20   235.0     c11   0.0       0.0     NaN
# 69      1        20    52.0      c9   0.0       0.0     NaN
# 70      0         0     NaN      c8   0.0       0.0     NaN
# 71      1        20     3.0      c7   0.0       0.0     NaN
# 72      0         0     NaN      c5   0.0       0.0     NaN
# 73      1        20    60.0      c8   0.0       0.0     NaN
# 74      0         0     NaN      c5   0.0       0.0     NaN
# 75      1        20     5.0      c6   1.0      20.0    11.0
# 76      0         0     NaN     c10   0.0       0.0     NaN
# 77      1        20    11.0      c5   0.0       0.0     NaN
# 78      0         0     NaN      c8   0.0       0.0     NaN
# 79      1        20    19.0      c7   0.0       0.0     NaN
# 80      1        20   107.0      c7   0.0       0.0     NaN
# 81      0         0     NaN      c8   0.0       0.0     NaN
# 82      0         0     NaN      c5   0.0       0.0     NaN
# 83      1        20    39.0      c9   0.0       0.0     NaN
# 84      0         0     NaN      c8   0.0       0.0     NaN
# 85      1        20    20.0      c6   0.0       0.0     NaN
# 86      1        20    74.0     c10   0.0       0.0     NaN
# 87      0         0     NaN      c8   0.0       0.0     NaN
# 88      0         0     NaN      c6   0.0       0.0     NaN
# 89      1        20    13.0      c5   0.0       0.0     NaN
# 90      0         0     NaN      c7   0.0       0.0     NaN
# 91      0         0     NaN      c8   0.0       0.0     NaN
# 92      1        20   179.0      c5   0.0       0.0     NaN
# 93      1        20    37.0      c8   0.0       0.0     NaN
# 94      1        20    20.0      c9   1.0      20.0    79.0
# 95      1        20    11.0      c8   0.0       0.0     NaN
# 96      1        20    82.0      c6   0.0       0.0     NaN
# 97      0         0     NaN      c7   0.0       0.0     NaN
# 98      1        20    23.0      c7   0.0       0.0     NaN
# 99      0         0     NaN      c7   0.0       0.0     NaN
# 100     1        20    44.0      c5   0.0       0.0     NaN
# 101     1        20    44.0      c8   0.0       0.0     NaN

# %%
# Create dataframes for the least and most relevant preference tests

# %%
least_df = df[df['test type'] == 'L'].copy()
least_df
# Out:
#      round  test                   search term              scope test type  \
# 1        1     1                     influenza         very broad         L
# 3        1     1                    long covid              broad         L
# 5        1     1          malaria therapeutics      very specific         L
# 7        1     2                        asthma         very broad         L
# 9        1     2   naegleria fowleri infection      very specific         L
# 11       1     2             zika microcephaly  somewhat specific         L
# 13       1     3      allergen skin prick test  somewhat specific         L
# 15       1     3             allergy treatment              broad         L
# 17       1     3      sublingual immunotherapy      very specific         L
# 19       1     4                          AIDS         very broad         L
# 21       1     4            immunotherapeutics  somewhat specific         L
# 23       1     4               t-cell function              broad         L
# 25       1     5             addison's disease      very specific         L
# 27       1     5                        cancer         very broad         L
# 29       1     5         myocardial infarction              broad         L
# 31       1     6               dendritic cells         very broad         L
# 33       1     6                    mast cells              broad         L
# 35       1     6   rational cancer drug design  somewhat specific         L
# 37       1     7                  metabolomics         very broad         L
# 39       1     7                   pinealocyte      very specific         L
# 41       1     7  plasmacytoid dendritic cells  somewhat specific         L
# 43       1     8                          gwas              broad         L
# 45       1     8                 mycobacterium         very broad         L
# 47       1     8          tuberculin skin test  somewhat specific         L
# 49       1     9                           hiv         very broad         L
# 51       1     9                     influenza         very broad         L
# 53       1     9                    long covid              broad         L
# 55       2     1                     influenza         very broad         L
# 57       2     1                    long covid              broad         L
# 59       2     1          malaria therapeutics      very specific         L
# 61       2     2             allergy treatment              broad         L
# 63       2     2                        asthma         very broad         L
# 65       2     2             zika microcephaly  somewhat specific         L
# 67       2     3                          AIDS         very broad         L
# 69       2     3      allergen skin prick test  somewhat specific         L
# 71       2     3      sublingual immunotherapy      very specific         L
# 73       2     4             addison's disease      very specific         L
# 75       2     4                        cancer         very broad         L
# 77       2     4               t-cell function              broad         L
# 79       2     5               dendritic cells         very broad         L
# 81       2     5         myocardial infarction              broad         L
# 83       2     5   rational cancer drug design  somewhat specific         L
# 85       2     6                    mast cells              broad         L
# 87       2     6                  metabolomics         very broad         L
# 89       2     6  plasmacytoid dendritic cells  somewhat specific         L
# 91       2     7                          gwas              broad         L
# 93       2     7                 mycobacterium         very broad         L
# 95       2     7          tuberculin skin test  somewhat specific         L
# 97       2     8                           hiv         very broad         L
# 99       2     8                     influenza         very broad         L
# 101      2     8                    long covid              broad         L
#
#     combo 1  ps 1  pct ps 1  time 1 combo 2  ps 2  pct ps 2  time 2 combo 3  \
# 1        c3     2        40      57      c4     2        40    34.0      c1
# 3        c2     2        40       9      c3     1        20    77.0      c4
# 5        c1     2        40      27      c4     1        20    10.0      c2
# 7        c5     3        60      19      c1     2        40     9.0      c4
# 9       c11     4        80      14     c10     1        20    98.0     c14
# 11       c4     4        80       8      c2     1        20    28.0      c1
# 13       c1     2        40      37      c4     1        20    12.0      c2
# 15       c2     3        60      25      c3     1        20    23.0      c1
# 17       c4     4        80      17      c3     1        20    23.0      c1
# 19       c4     4        80      59      c1     1        20     6.0      c3
# 21      c15     3        60      11      c1     2        40    16.0      c2
# 23       c3     3        60      12      c2     1        20    10.0      c4
# 25       c4     2        40      26      c1     1        20    11.0      c2
# 27       c3     2        40      16      c4     2        40    14.0      c2
# 29       c3     2        40      12      c4     2        40     7.0      c2
# 31       c1     2        40      51      c3     1        20    14.0      c4
# 33       c4     2        40      41      c1     1        20     7.0      c2
# 35       c4     4        80      19      c2     1        20    42.0      c3
# 37       c5     3        60       8      c3     1        20    17.0      c4
# 39       c5     2        40       6      c1     2        40    30.0     c10
# 41       c2     3        60       7      c3     1        20    16.0      c4
# 43       c1     3        60      22      c2     1        20    10.0      c3
# 45       c3     2        40      10      c4     2        40    27.0      c1
# 47       c2     3        60      15      c3     1        20     4.0      c1
# 49       c4     3        60      10      c1     1        20    10.0      c3
# 51       c2     4        80      10      c4     1        20    13.0      c3
# 53       c4     3        60      12      c1     1        20    16.0      c2
# 55       c9     2        40      47      c5     2        40    14.0      c7
# 57       c7     3        60      21      c5     2        40    17.0      c6
# 59       c9     2        40      23      c5     2        40     9.0      c7
# 61       c6     3        60      21      c8     1        20    37.0      c5
# 63      c10     2        40       9      c8     1        20    16.0      c9
# 65       c5     3        60       9      c7     2        40    10.0      c8
# 67       c5     2        40      38      c7     1        20    64.0      c8
# 69      c11     2        40      70      c8     2        40    17.0     c10
# 71       c6     3        60      28      c5     1        20    34.0      c8
# 73      c10     2        40       5      c5     2        40    18.0      c7
# 75       c5     2        40      13      c7     1        20    26.0      c8
# 77      c10     3        60      16      c8     1        20    20.0      c9
# 79       c5     2        40      10      c6     2        40    15.0      c8
# 81       c5     3        60      28      c7     2        40     4.0      c6
# 83       c5     3        60      17      c8     1        20     9.0     c10
# 85       c5     2        40      44      c7     2        40    16.0      c8
# 87      c10     4        80      17     c13     1        20    27.0      c9
# 89       c6     2        40      21      c7     2        40    49.0      c8
# 91       c6     4        80      20      c5     1        20    34.0      c7
# 93       c5     2        40      23      c6     2        40     8.0      c7
# 95       c5     3        60      37      c7     1        20    11.0      c9
# 97       c8     4        80      28      c5     1        20     7.0      c6
# 99       c9     3        60      26      c8     2        40    55.0      c5
# 101      c6     2        40      35      c7     2        40    44.0      c5
#
#      ps 3  pct ps 3  time 3 combo 4  ps 4  pct ps 4  time 4
# 1       1        20    23.0      c2   0.0       0.0     NaN
# 3       1        20    95.0      c1   1.0      20.0    16.0
# 5       1        20     4.0      c3   1.0      20.0    31.0
# 7       0         0     NaN      c2   0.0       0.0     NaN
# 9       0         0     NaN      c1   0.0       0.0     NaN
# 11      0         0     NaN      c3   0.0       0.0     NaN
# 13      1        20    49.0      c3   1.0      20.0    22.0
# 15      1        20     4.0      c4   0.0       0.0     NaN
# 17      0         0     NaN      c2   0.0       0.0     NaN
# 19      0         0     NaN      c2   0.0       0.0     NaN
# 21      0         0     NaN     NaN   NaN       NaN     NaN
# 23      1        20   130.0      c1   0.0       0.0     NaN
# 25      1        20    35.0      c3   1.0      20.0    34.0
# 27      1        20    29.0      c1   0.0       0.0     NaN
# 29      1        20    33.0      c1   0.0       0.0     NaN
# 31      1        20     8.0      c2   1.0      20.0     6.0
# 33      1        20    17.0      c3   1.0      20.0     5.0
# 35      0         0     NaN      c1   0.0       0.0     NaN
# 37      1        20     9.0      c1   0.0       0.0     NaN
# 39      1        20     6.0      c4   0.0       0.0     NaN
# 41      1        20     7.0      c1   0.0       0.0     NaN
# 43      1        20     6.0      c4   0.0       0.0     NaN
# 45      1        20     3.0      c2   0.0       0.0     NaN
# 47      1        20     5.0      c4   0.0       0.0     NaN
# 49      1        20    45.0      c2   0.0       0.0     NaN
# 51      0         0     NaN      c1   0.0       0.0     NaN
# 53      1        20    13.0      c3   0.0       0.0     NaN
# 55      1        20    13.0      c8   0.0       0.0     NaN
# 57      0         0     NaN      c8   0.0       0.0     NaN
# 59      1        20    28.0      c6   0.0       0.0     NaN
# 61      1        20    15.0      c7   0.0       0.0     NaN
# 63      1        20    13.0      c7   1.0      20.0    46.0
# 65      0         0     NaN      c9   0.0       0.0     NaN
# 67      1        20    44.0      c6   1.0      20.0    21.0
# 69      1        20    52.0      c9   0.0       0.0     NaN
# 71      1        20     3.0      c7   0.0       0.0     NaN
# 73      1        20    60.0      c8   0.0       0.0     NaN
# 75      1        20     5.0      c6   1.0      20.0    11.0
# 77      1        20    11.0      c5   0.0       0.0     NaN
# 79      1        20    19.0      c7   0.0       0.0     NaN
# 81      0         0     NaN      c8   0.0       0.0     NaN
# 83      1        20    39.0      c9   0.0       0.0     NaN
# 85      1        20    20.0      c6   0.0       0.0     NaN
# 87      0         0     NaN      c8   0.0       0.0     NaN
# 89      1        20    13.0      c5   0.0       0.0     NaN
# 91      0         0     NaN      c8   0.0       0.0     NaN
# 93      1        20    37.0      c8   0.0       0.0     NaN
# 95      1        20    11.0      c8   0.0       0.0     NaN
# 97      0         0     NaN      c7   0.0       0.0     NaN
# 99      0         0     NaN      c7   0.0       0.0     NaN
# 101     1        20    44.0      c8   0.0       0.0     NaN

# %%
most_df = df[df['test type'] != 'L'].copy()
most_df
# Out:
#      round  test                   search term              scope test type  \
# 0        1     1                     influenza         very broad        M
# 2        1     1                    long covid              broad        M
# 4        1     1          malaria therapeutics      very specific        M
# 6        1     2                        asthma         very broad        M
# 8        1     2   naegleria fowleri infection      very specific        M
# 10       1     2             zika microcephaly  somewhat specific        M
# 12       1     3      allergen skin prick test  somewhat specific        M
# 14       1     3             allergy treatment              broad        M
# 16       1     3      sublingual immunotherapy      very specific        M
# 18       1     4                          AIDS         very broad        M
# 20       1     4            immunotherapeutics  somewhat specific        M
# 22       1     4               t-cell function              broad        M
# 24       1     5             addison's disease      very specific        M
# 26       1     5                        cancer         very broad        M
# 28       1     5         myocardial infarction              broad        M
# 30       1     6               dendritic cells         very broad        M
# 32       1     6                    mast cells              broad        M
# 34       1     6   rational cancer drug design  somewhat specific        M
# 36       1     7                  metabolomics         very broad        M
# 38       1     7                   pinealocyte      very specific        M
# 40       1     7  plasmacytoid dendritic cells  somewhat specific        M
# 42       1     8                          gwas              broad        M
# 44       1     8                 mycobacterium         very broad        M
# 46       1     8          tuberculin skin test  somewhat specific        M
# 48       1     9                           hiv         very broad        M
# 50       1     9                     influenza         very broad        M
# 52       1     9                    long covid              broad        M
# 54       2     1                     influenza         very broad         M
# 56       2     1                    long covid              broad         M
# 58       2     1          malaria therapeutics      very specific         M
# 60       2     2             allergy treatment              broad         M
# 62       2     2                        asthma         very broad         M
# 64       2     2             zika microcephaly  somewhat specific         M
# 66       2     3                          AIDS         very broad         M
# 68       2     3      allergen skin prick test  somewhat specific         M
# 70       2     3      sublingual immunotherapy      very specific         M
# 72       2     4             addison's disease      very specific         M
# 74       2     4                        cancer         very broad         M
# 76       2     4               t-cell function              broad         M
# 78       2     5               dendritic cells         very broad         M
# 80       2     5         myocardial infarction              broad         M
# 82       2     5   rational cancer drug design  somewhat specific         M
# 84       2     6                    mast cells              broad         M
# 86       2     6                  metabolomics         very broad         M
# 88       2     6  plasmacytoid dendritic cells  somewhat specific         M
# 90       2     7                          gwas              broad         M
# 92       2     7                 mycobacterium         very broad         M
# 94       2     7          tuberculin skin test  somewhat specific         M
# 96       2     8                           hiv         very broad         M
# 98       2     8                     influenza         very broad         M
# 100      2     8                    long covid              broad         M
#
#     combo 1  ps 1  pct ps 1  time 1 combo 2  ps 2  pct ps 2  time 2 combo 3  \
# 0        c1     2        40      34      c3     1        20   156.0      c4
# 2        c3     2        40     107      c4     2        40   166.0      c2
# 4        c2     2        40      31      c4     1        20    27.0      c1
# 6        c4     3        60      56      c5     1        20    52.0      c1
# 8       c11     3        60      23      c1     2        40    72.0     c10
# 10       c1     3        60      40      c2     1        20    36.0      c3
# 12       c3     2        40     121      c4     1        20    39.0      c1
# 14       c1     2        40      51      c3     1        20    52.0      c4
# 16       c1     4        80      40      c4     1        20    26.0      c2
# 18       c4     2        40      88      c1     2        40   127.0      c2
# 20       c1     2        40      20      c2     2        40    97.0     c15
# 22       c3     2        40     117      c4     2        40    45.0      c1
# 24       c2     4        80     118      c1     1        20    45.0      c3
# 26       c1     3        60      29      c4     1        20    24.0      c2
# 28       c4     2        40      69      c1     2        40    40.0      c3
# 30       c1     3        60     167      c4     1        20    66.0      c3
# 32       c1     4        80      59      c2     1        20    39.0      c3
# 34       c3     3        60      52      c1     1        20    24.0      c4
# 36       c1     3        60      27      c5     2        40   105.0      c3
# 38      c10     2        40      31      c5     2        40     5.0      c1
# 40       c4     3        60      15      c2     2        40    22.0      c1
# 42       c4     3        60      36      c2     1        20    17.0      c3
# 44       c1     3        60      28      c2     2        40    51.0      c3
# 46       c1     2        40      23      c4     2        40    45.0      c2
# 48       c1     4        80      49      c3     1        20    59.0      c4
# 50       c3     3        60      19      c1     2        40    16.0      c4
# 52       c1     3        60      22      c4     1        20     4.0      c2
# 54       c8     4        80      63      c7     1        20    52.0      c9
# 56       c7     2        40      19      c8     2        40    39.0      c6
# 58       c7     2        40      35      c5     1        20    88.0      c6
# 60       c5     2        40      92      c6     2        40    57.0      c8
# 62       c9     2        40      30      c8     2        40    17.0     c10
# 64       c8     3        60      21      c9     1        20     2.0      c7
# 66       c6     2        40     153      c8     2        40    90.0      c7
# 68       c9     3        60      30      c8     1        20    98.0     c10
# 70       c5     4        80      62      c6     1        20    17.0      c7
# 72       c7     4        80      83      c8     1        20    52.0     c10
# 74       c7     3        60      71      c6     2        40    31.0      c8
# 76       c8     5       100      42      c5     0         0     NaN      c9
# 78       c6     3        60      42      c5     2        40    33.0      c7
# 80       c6     3        60      54      c5     1        20    14.0      c8
# 82       c8     3        60      40      c9     2        40    83.0     c10
# 84       c6     4        80      80      c5     1        20    24.0      c7
# 86       c8     2        40      44      c9     2        40    25.0     c13
# 88       c7     3        60      31      c8     2        40    78.0      c5
# 90       c5     5       100      68      c8     0         0     NaN      c6
# 92       c8     2        40      34      c6     2        40    44.0      c7
# 94       c7     2        40      33      c5     1        20   222.0      c8
# 96       c8     2        40     136      c5     2        40    23.0      c7
# 98       c8     2        40      61      c9     2        40    25.0      c5
# 100      c8     3        60      28      c6     1        20    87.0      c7
#
#      ps 3  pct ps 3  time 3 combo 4  ps 4  pct ps 4  time 4
# 0       1        20   105.0      c2   1.0      20.0    71.0
# 2       1        20    18.0      c1   0.0       0.0     NaN
# 4       1        20    50.0      c3   1.0      20.0    76.0
# 6       1        20    24.0      c2   0.0       0.0     NaN
# 8       0         0     NaN     c14   0.0       0.0     NaN
# 10      1        20    35.0      c4   0.0       0.0     NaN
# 12      1        20    52.0      c2   1.0      20.0    71.0
# 14      1        20    25.0      c2   1.0      20.0    31.0
# 16      0         0     NaN      c3   0.0       0.0     NaN
# 18      1        20    14.0      c3   0.0       0.0     NaN
# 20      1        20    58.0     NaN   NaN       NaN     NaN
# 22      1        20    16.0      c2   0.0       0.0     NaN
# 24      0         0     NaN      c4   0.0       0.0     NaN
# 26      1        20    46.0      c3   0.0       0.0     NaN
# 28      1        20    32.0      c2   0.0       0.0     NaN
# 30      1        20    45.0      c2   0.0       0.0     NaN
# 32      0         0     NaN      c4   0.0       0.0     NaN
# 34      1        20    58.0      c2   0.0       0.0     NaN
# 36      0         0     NaN      c4   0.0       0.0     NaN
# 38      1        20     7.0      c4   0.0       0.0     NaN
# 40      0         0     NaN      c3   0.0       0.0     NaN
# 42      1        20     9.0      c1   0.0       0.0     NaN
# 44      0         0     NaN      c4   0.0       0.0     NaN
# 46      1        20    18.0      c3   0.0       0.0     NaN
# 48      0         0     NaN      c2   0.0       0.0     NaN
# 50      0         0     NaN      c2   0.0       0.0     NaN
# 52      1        20    20.0      c3   0.0       0.0     NaN
# 54      0         0     NaN      c5   0.0       0.0     NaN
# 56      1        20    56.0      c5   0.0       0.0     NaN
# 58      1        20   106.0      c9   1.0      20.0    28.0
# 60      1        20    26.0      c7   0.0       0.0     NaN
# 62      1        20    39.0      c7   0.0       0.0     NaN
# 64      1        20    16.0      c5   0.0       0.0     NaN
# 66      1        20   124.0      c5   0.0       0.0     NaN
# 68      1        20   235.0     c11   0.0       0.0     NaN
# 70      0         0     NaN      c8   0.0       0.0     NaN
# 72      0         0     NaN      c5   0.0       0.0     NaN
# 74      0         0     NaN      c5   0.0       0.0     NaN
# 76      0         0     NaN     c10   0.0       0.0     NaN
# 78      0         0     NaN      c8   0.0       0.0     NaN
# 80      1        20   107.0      c7   0.0       0.0     NaN
# 82      0         0     NaN      c5   0.0       0.0     NaN
# 84      0         0     NaN      c8   0.0       0.0     NaN
# 86      1        20    74.0     c10   0.0       0.0     NaN
# 88      0         0     NaN      c6   0.0       0.0     NaN
# 90      0         0     NaN      c7   0.0       0.0     NaN
# 92      1        20   179.0      c5   0.0       0.0     NaN
# 94      1        20    20.0      c9   1.0      20.0    79.0
# 96      1        20    82.0      c6   0.0       0.0     NaN
# 98      1        20    23.0      c7   0.0       0.0     NaN
# 100     1        20    44.0      c5   0.0       0.0     NaN

# %% [markdown]
# ## 3. Combinations deemed most or least relevant

# %%
# Find the number of participants that considered each combination as the least relevant one

# %%
# Initialize a dictionary to store combo quantities
least_combos = {}

# Iterate over rows in the DataFrame
for index, row in least_df.iterrows():
    # Iterate over shop columns and quantity columns
    for i in range(1, 5):
        combo = row[f'combo {i}']
        ps = row[f'ps {i}']
        # Update dictionary
        least_combos[combo] = least_combos.get(combo, 0) + ps

# Participants that selected each combination as the least relevant one
print("Least relevant preference tests: combinations and number of participants who selected them")
print("Combination: participants")
for combo, ps in least_combos.items():
    print(f"{combo}: {ps}")
# Out:
# Least relevant preference tests: combinations and number of participants who selected them
# Combination: participants
# c3: 24.0
# c4: 42.0
# c1: 25.0
# c2: 27.0
# c5: 43.0
# c11: 6
# c10: 15
# c14: 0
# c15: 3
# nan: nan
# c9: 10.0
# c7: 21.0
# c8: 18.0
# c6: 20.0
# c13: 1

# %%
# Find the number of participants that considered each combination as the most relevant one

# %%
# Initialize a dictionary to store combo quantities
most_combos = {}

# Iterate over rows in the DataFrame
for index, row in most_df.iterrows():
    # Iterate over shop columns and quantity columns
    for i in range(1, 5):
        combo = row[f'combo {i}']
        ps = row[f'ps {i}']
        # Update dictionary
        most_combos[combo] = most_combos.get(combo, 0) + ps

# Participants that selected each combination as the most relevant one
print("Most relevant preference tests: combinations and number of participants who selected them")
print("Combination: participants")
for combo, ps in most_combos.items():
    print(f"{combo}: {ps}")
# Out:
# Most relevant preference tests: combinations and number of participants who selected them
# Combination: participants
# c1: 53.0
# c3: 20.0
# c4: 28.0
# c2: 23.0
# c5: 25.0
# c11: 3.0
# c10: 4.0
# c14: 0.0
# c15: 1
# nan: nan
# c8: 39.0
# c7: 22.0
# c9: 14.0
# c6: 22.0
# c13: 1

# %% [markdown]
# ## 4. Combinations that were not deemed most or least relevant

# %%
# Combinations that were not considered to be least relevant

# %%
# Find rows where any of the ps are '0'
rows_with_zero_ps_least = least_df[(least_df['ps 1'] == 0) | 
                                   (least_df['ps 2'] == 0) | (least_df['ps 3'] == 0) | (least_df['ps 4'] == 0)]
rows_with_zero_ps_least
# Out:
#      round  test                   search term              scope test type  \
# 1        1     1                     influenza         very broad         L
# 7        1     2                        asthma         very broad         L
# 9        1     2   naegleria fowleri infection      very specific         L
# 11       1     2             zika microcephaly  somewhat specific         L
# 15       1     3             allergy treatment              broad         L
# 17       1     3      sublingual immunotherapy      very specific         L
# 19       1     4                          AIDS         very broad         L
# 21       1     4            immunotherapeutics  somewhat specific         L
# 23       1     4               t-cell function              broad         L
# 27       1     5                        cancer         very broad         L
# 29       1     5         myocardial infarction              broad         L
# 35       1     6   rational cancer drug design  somewhat specific         L
# 37       1     7                  metabolomics         very broad         L
# 39       1     7                   pinealocyte      very specific         L
# 41       1     7  plasmacytoid dendritic cells  somewhat specific         L
# 43       1     8                          gwas              broad         L
# 45       1     8                 mycobacterium         very broad         L
# 47       1     8          tuberculin skin test  somewhat specific         L
# 49       1     9                           hiv         very broad         L
# 51       1     9                     influenza         very broad         L
# 53       1     9                    long covid              broad         L
# 55       2     1                     influenza         very broad         L
# 57       2     1                    long covid              broad         L
# 59       2     1          malaria therapeutics      very specific         L
# 61       2     2             allergy treatment              broad         L
# 65       2     2             zika microcephaly  somewhat specific         L
# 69       2     3      allergen skin prick test  somewhat specific         L
# 71       2     3      sublingual immunotherapy      very specific         L
# 73       2     4             addison's disease      very specific         L
# 77       2     4               t-cell function              broad         L
# 79       2     5               dendritic cells         very broad         L
# 81       2     5         myocardial infarction              broad         L
# 83       2     5   rational cancer drug design  somewhat specific         L
# 85       2     6                    mast cells              broad         L
# 87       2     6                  metabolomics         very broad         L
# 89       2     6  plasmacytoid dendritic cells  somewhat specific         L
# 91       2     7                          gwas              broad         L
# 93       2     7                 mycobacterium         very broad         L
# 95       2     7          tuberculin skin test  somewhat specific         L
# 97       2     8                           hiv         very broad         L
# 99       2     8                     influenza         very broad         L
# 101      2     8                    long covid              broad         L
#
#     combo 1  ps 1  pct ps 1  time 1 combo 2  ps 2  pct ps 2  time 2 combo 3  \
# 1        c3     2        40      57      c4     2        40    34.0      c1
# 7        c5     3        60      19      c1     2        40     9.0      c4
# 9       c11     4        80      14     c10     1        20    98.0     c14
# 11       c4     4        80       8      c2     1        20    28.0      c1
# 15       c2     3        60      25      c3     1        20    23.0      c1
# 17       c4     4        80      17      c3     1        20    23.0      c1
# 19       c4     4        80      59      c1     1        20     6.0      c3
# 21      c15     3        60      11      c1     2        40    16.0      c2
# 23       c3     3        60      12      c2     1        20    10.0      c4
# 27       c3     2        40      16      c4     2        40    14.0      c2
# 29       c3     2        40      12      c4     2        40     7.0      c2
# 35       c4     4        80      19      c2     1        20    42.0      c3
# 37       c5     3        60       8      c3     1        20    17.0      c4
# 39       c5     2        40       6      c1     2        40    30.0     c10
# 41       c2     3        60       7      c3     1        20    16.0      c4
# 43       c1     3        60      22      c2     1        20    10.0      c3
# 45       c3     2        40      10      c4     2        40    27.0      c1
# 47       c2     3        60      15      c3     1        20     4.0      c1
# 49       c4     3        60      10      c1     1        20    10.0      c3
# 51       c2     4        80      10      c4     1        20    13.0      c3
# 53       c4     3        60      12      c1     1        20    16.0      c2
# 55       c9     2        40      47      c5     2        40    14.0      c7
# 57       c7     3        60      21      c5     2        40    17.0      c6
# 59       c9     2        40      23      c5     2        40     9.0      c7
# 61       c6     3        60      21      c8     1        20    37.0      c5
# 65       c5     3        60       9      c7     2        40    10.0      c8
# 69      c11     2        40      70      c8     2        40    17.0     c10
# 71       c6     3        60      28      c5     1        20    34.0      c8
# 73      c10     2        40       5      c5     2        40    18.0      c7
# 77      c10     3        60      16      c8     1        20    20.0      c9
# 79       c5     2        40      10      c6     2        40    15.0      c8
# 81       c5     3        60      28      c7     2        40     4.0      c6
# 83       c5     3        60      17      c8     1        20     9.0     c10
# 85       c5     2        40      44      c7     2        40    16.0      c8
# 87      c10     4        80      17     c13     1        20    27.0      c9
# 89       c6     2        40      21      c7     2        40    49.0      c8
# 91       c6     4        80      20      c5     1        20    34.0      c7
# 93       c5     2        40      23      c6     2        40     8.0      c7
# 95       c5     3        60      37      c7     1        20    11.0      c9
# 97       c8     4        80      28      c5     1        20     7.0      c6
# 99       c9     3        60      26      c8     2        40    55.0      c5
# 101      c6     2        40      35      c7     2        40    44.0      c5
#
#      ps 3  pct ps 3  time 3 combo 4  ps 4  pct ps 4  time 4
# 1       1        20    23.0      c2   0.0       0.0     NaN
# 7       0         0     NaN      c2   0.0       0.0     NaN
# 9       0         0     NaN      c1   0.0       0.0     NaN
# 11      0         0     NaN      c3   0.0       0.0     NaN
# 15      1        20     4.0      c4   0.0       0.0     NaN
# 17      0         0     NaN      c2   0.0       0.0     NaN
# 19      0         0     NaN      c2   0.0       0.0     NaN
# 21      0         0     NaN     NaN   NaN       NaN     NaN
# 23      1        20   130.0      c1   0.0       0.0     NaN
# 27      1        20    29.0      c1   0.0       0.0     NaN
# 29      1        20    33.0      c1   0.0       0.0     NaN
# 35      0         0     NaN      c1   0.0       0.0     NaN
# 37      1        20     9.0      c1   0.0       0.0     NaN
# 39      1        20     6.0      c4   0.0       0.0     NaN
# 41      1        20     7.0      c1   0.0       0.0     NaN
# 43      1        20     6.0      c4   0.0       0.0     NaN
# 45      1        20     3.0      c2   0.0       0.0     NaN
# 47      1        20     5.0      c4   0.0       0.0     NaN
# 49      1        20    45.0      c2   0.0       0.0     NaN
# 51      0         0     NaN      c1   0.0       0.0     NaN
# 53      1        20    13.0      c3   0.0       0.0     NaN
# 55      1        20    13.0      c8   0.0       0.0     NaN
# 57      0         0     NaN      c8   0.0       0.0     NaN
# 59      1        20    28.0      c6   0.0       0.0     NaN
# 61      1        20    15.0      c7   0.0       0.0     NaN
# 65      0         0     NaN      c9   0.0       0.0     NaN
# 69      1        20    52.0      c9   0.0       0.0     NaN
# 71      1        20     3.0      c7   0.0       0.0     NaN
# 73      1        20    60.0      c8   0.0       0.0     NaN
# 77      1        20    11.0      c5   0.0       0.0     NaN
# 79      1        20    19.0      c7   0.0       0.0     NaN
# 81      0         0     NaN      c8   0.0       0.0     NaN
# 83      1        20    39.0      c9   0.0       0.0     NaN
# 85      1        20    20.0      c6   0.0       0.0     NaN
# 87      0         0     NaN      c8   0.0       0.0     NaN
# 89      1        20    13.0      c5   0.0       0.0     NaN
# 91      0         0     NaN      c8   0.0       0.0     NaN
# 93      1        20    37.0      c8   0.0       0.0     NaN
# 95      1        20    11.0      c8   0.0       0.0     NaN
# 97      0         0     NaN      c7   0.0       0.0     NaN
# 99      0         0     NaN      c7   0.0       0.0     NaN
# 101     1        20    44.0      c8   0.0       0.0     NaN

# %%
print("Least relevant preference tests\n")
# Iterate through each search term
for term in rows_with_zero_ps_least['search term'].unique():
    print(f"search term: {term}")
    zero_ps_combos = []
    for i in range(1, 5):  # Iterate through ps columns
        ps_col = f'ps {i}'
        combo_col = f'combo {i}'
        # Filter rows where ps is 0 and add corresponding combo to the list
        zero_ps_combos.extend(rows_with_zero_ps_least[(rows_with_zero_ps_least['search term'] == term) & 
                                                      (rows_with_zero_ps_least[ps_col] == 0)][combo_col])
    # Display unique combos with ps equal to 0 for the search term
    print(f"combos with ps equal to zero: {set(zero_ps_combos)}")
    print()
# Out:
# Least relevant preference tests
#
# search term: influenza
# combos with ps equal to zero: {'c8', 'c2', 'c5', 'c1', 'c3', 'c7'}
#
# search term: asthma
# combos with ps equal to zero: {'c2', 'c4'}
#
# search term: naegleria fowleri infection
# combos with ps equal to zero: {'c14', 'c1'}
#
# search term: zika microcephaly
# combos with ps equal to zero: {'c8', 'c9', 'c3', 'c1'}
#
# search term: allergy treatment
# combos with ps equal to zero: {'c7', 'c4'}
#
# search term: sublingual immunotherapy
# combos with ps equal to zero: {'c7', 'c2', 'c1'}
#
# search term: AIDS
# combos with ps equal to zero: {'c3', 'c2'}
#
# search term: immunotherapeutics
# combos with ps equal to zero: {'c2'}
#
# search term: t-cell function
# combos with ps equal to zero: {'c5', 'c1'}
#
# search term: cancer
# combos with ps equal to zero: {'c1'}
#
# search term: myocardial infarction
# combos with ps equal to zero: {'c8', 'c6', 'c1'}
#
# search term: rational cancer drug design
# combos with ps equal to zero: {'c9', 'c3', 'c1'}
#
# search term: metabolomics
# combos with ps equal to zero: {'c8', 'c9', 'c1'}
#
# search term: pinealocyte
# combos with ps equal to zero: {'c4'}
#
# search term: plasmacytoid dendritic cells
# combos with ps equal to zero: {'c5', 'c1'}
#
# search term: gwas
# combos with ps equal to zero: {'c8', 'c7', 'c4'}
#
# search term: mycobacterium
# combos with ps equal to zero: {'c8', 'c2'}
#
# search term: tuberculin skin test
# combos with ps equal to zero: {'c8', 'c4'}
#
# search term: hiv
# combos with ps equal to zero: {'c7', 'c2', 'c6'}
#
# search term: long covid
# combos with ps equal to zero: {'c8', 'c3', 'c6'}
#
# search term: malaria therapeutics
# combos with ps equal to zero: {'c6'}
#
# search term: allergen skin prick test
# combos with ps equal to zero: {'c9'}
#
# search term: addison's disease
# combos with ps equal to zero: {'c8'}
#
# search term: dendritic cells
# combos with ps equal to zero: {'c7'}
#
# search term: mast cells
# combos with ps equal to zero: {'c6'}

# %%
# Combinations that were not considered to be most relevant

# %%
# Find rows where any of the ps are '0'
rows_with_zero_ps_most = most_df[(most_df['ps 1'] == 0) | 
                                   (most_df['ps 2'] == 0) | (most_df['ps 3'] == 0) | (most_df['ps 4'] == 0)]
rows_with_zero_ps_most
# Out:
#      round  test                   search term              scope test type  \
# 2        1     1                    long covid              broad        M
# 6        1     2                        asthma         very broad        M
# 8        1     2   naegleria fowleri infection      very specific        M
# 10       1     2             zika microcephaly  somewhat specific        M
# 16       1     3      sublingual immunotherapy      very specific        M
# 18       1     4                          AIDS         very broad        M
# 22       1     4               t-cell function              broad        M
# 24       1     5             addison's disease      very specific        M
# 26       1     5                        cancer         very broad        M
# 28       1     5         myocardial infarction              broad        M
# 30       1     6               dendritic cells         very broad        M
# 32       1     6                    mast cells              broad        M
# 34       1     6   rational cancer drug design  somewhat specific        M
# 36       1     7                  metabolomics         very broad        M
# 38       1     7                   pinealocyte      very specific        M
# 40       1     7  plasmacytoid dendritic cells  somewhat specific        M
# 42       1     8                          gwas              broad        M
# 44       1     8                 mycobacterium         very broad        M
# 46       1     8          tuberculin skin test  somewhat specific        M
# 48       1     9                           hiv         very broad        M
# 50       1     9                     influenza         very broad        M
# 52       1     9                    long covid              broad        M
# 54       2     1                     influenza         very broad         M
# 56       2     1                    long covid              broad         M
# 60       2     2             allergy treatment              broad         M
# 62       2     2                        asthma         very broad         M
# 64       2     2             zika microcephaly  somewhat specific         M
# 66       2     3                          AIDS         very broad         M
# 68       2     3      allergen skin prick test  somewhat specific         M
# 70       2     3      sublingual immunotherapy      very specific         M
# 72       2     4             addison's disease      very specific         M
# 74       2     4                        cancer         very broad         M
# 76       2     4               t-cell function              broad         M
# 78       2     5               dendritic cells         very broad         M
# 80       2     5         myocardial infarction              broad         M
# 82       2     5   rational cancer drug design  somewhat specific         M
# 84       2     6                    mast cells              broad         M
# 86       2     6                  metabolomics         very broad         M
# 88       2     6  plasmacytoid dendritic cells  somewhat specific         M
# 90       2     7                          gwas              broad         M
# 92       2     7                 mycobacterium         very broad         M
# 96       2     8                           hiv         very broad         M
# 98       2     8                     influenza         very broad         M
# 100      2     8                    long covid              broad         M
#
#     combo 1  ps 1  pct ps 1  time 1 combo 2  ps 2  pct ps 2  time 2 combo 3  \
# 2        c3     2        40     107      c4     2        40   166.0      c2
# 6        c4     3        60      56      c5     1        20    52.0      c1
# 8       c11     3        60      23      c1     2        40    72.0     c10
# 10       c1     3        60      40      c2     1        20    36.0      c3
# 16       c1     4        80      40      c4     1        20    26.0      c2
# 18       c4     2        40      88      c1     2        40   127.0      c2
# 22       c3     2        40     117      c4     2        40    45.0      c1
# 24       c2     4        80     118      c1     1        20    45.0      c3
# 26       c1     3        60      29      c4     1        20    24.0      c2
# 28       c4     2        40      69      c1     2        40    40.0      c3
# 30       c1     3        60     167      c4     1        20    66.0      c3
# 32       c1     4        80      59      c2     1        20    39.0      c3
# 34       c3     3        60      52      c1     1        20    24.0      c4
# 36       c1     3        60      27      c5     2        40   105.0      c3
# 38      c10     2        40      31      c5     2        40     5.0      c1
# 40       c4     3        60      15      c2     2        40    22.0      c1
# 42       c4     3        60      36      c2     1        20    17.0      c3
# 44       c1     3        60      28      c2     2        40    51.0      c3
# 46       c1     2        40      23      c4     2        40    45.0      c2
# 48       c1     4        80      49      c3     1        20    59.0      c4
# 50       c3     3        60      19      c1     2        40    16.0      c4
# 52       c1     3        60      22      c4     1        20     4.0      c2
# 54       c8     4        80      63      c7     1        20    52.0      c9
# 56       c7     2        40      19      c8     2        40    39.0      c6
# 60       c5     2        40      92      c6     2        40    57.0      c8
# 62       c9     2        40      30      c8     2        40    17.0     c10
# 64       c8     3        60      21      c9     1        20     2.0      c7
# 66       c6     2        40     153      c8     2        40    90.0      c7
# 68       c9     3        60      30      c8     1        20    98.0     c10
# 70       c5     4        80      62      c6     1        20    17.0      c7
# 72       c7     4        80      83      c8     1        20    52.0     c10
# 74       c7     3        60      71      c6     2        40    31.0      c8
# 76       c8     5       100      42      c5     0         0     NaN      c9
# 78       c6     3        60      42      c5     2        40    33.0      c7
# 80       c6     3        60      54      c5     1        20    14.0      c8
# 82       c8     3        60      40      c9     2        40    83.0     c10
# 84       c6     4        80      80      c5     1        20    24.0      c7
# 86       c8     2        40      44      c9     2        40    25.0     c13
# 88       c7     3        60      31      c8     2        40    78.0      c5
# 90       c5     5       100      68      c8     0         0     NaN      c6
# 92       c8     2        40      34      c6     2        40    44.0      c7
# 96       c8     2        40     136      c5     2        40    23.0      c7
# 98       c8     2        40      61      c9     2        40    25.0      c5
# 100      c8     3        60      28      c6     1        20    87.0      c7
#
#      ps 3  pct ps 3  time 3 combo 4  ps 4  pct ps 4  time 4
# 2       1        20    18.0      c1   0.0       0.0     NaN
# 6       1        20    24.0      c2   0.0       0.0     NaN
# 8       0         0     NaN     c14   0.0       0.0     NaN
# 10      1        20    35.0      c4   0.0       0.0     NaN
# 16      0         0     NaN      c3   0.0       0.0     NaN
# 18      1        20    14.0      c3   0.0       0.0     NaN
# 22      1        20    16.0      c2   0.0       0.0     NaN
# 24      0         0     NaN      c4   0.0       0.0     NaN
# 26      1        20    46.0      c3   0.0       0.0     NaN
# 28      1        20    32.0      c2   0.0       0.0     NaN
# 30      1        20    45.0      c2   0.0       0.0     NaN
# 32      0         0     NaN      c4   0.0       0.0     NaN
# 34      1        20    58.0      c2   0.0       0.0     NaN
# 36      0         0     NaN      c4   0.0       0.0     NaN
# 38      1        20     7.0      c4   0.0       0.0     NaN
# 40      0         0     NaN      c3   0.0       0.0     NaN
# 42      1        20     9.0      c1   0.0       0.0     NaN
# 44      0         0     NaN      c4   0.0       0.0     NaN
# 46      1        20    18.0      c3   0.0       0.0     NaN
# 48      0         0     NaN      c2   0.0       0.0     NaN
# 50      0         0     NaN      c2   0.0       0.0     NaN
# 52      1        20    20.0      c3   0.0       0.0     NaN
# 54      0         0     NaN      c5   0.0       0.0     NaN
# 56      1        20    56.0      c5   0.0       0.0     NaN
# 60      1        20    26.0      c7   0.0       0.0     NaN
# 62      1        20    39.0      c7   0.0       0.0     NaN
# 64      1        20    16.0      c5   0.0       0.0     NaN
# 66      1        20   124.0      c5   0.0       0.0     NaN
# 68      1        20   235.0     c11   0.0       0.0     NaN
# 70      0         0     NaN      c8   0.0       0.0     NaN
# 72      0         0     NaN      c5   0.0       0.0     NaN
# 74      0         0     NaN      c5   0.0       0.0     NaN
# 76      0         0     NaN     c10   0.0       0.0     NaN
# 78      0         0     NaN      c8   0.0       0.0     NaN
# 80      1        20   107.0      c7   0.0       0.0     NaN
# 82      0         0     NaN      c5   0.0       0.0     NaN
# 84      0         0     NaN      c8   0.0       0.0     NaN
# 86      1        20    74.0     c10   0.0       0.0     NaN
# 88      0         0     NaN      c6   0.0       0.0     NaN
# 90      0         0     NaN      c7   0.0       0.0     NaN
# 92      1        20   179.0      c5   0.0       0.0     NaN
# 96      1        20    82.0      c6   0.0       0.0     NaN
# 98      1        20    23.0      c7   0.0       0.0     NaN
# 100     1        20    44.0      c5   0.0       0.0     NaN

# %%
print("Most relevant preference tests\n")

# Iterate through each search term
for term in rows_with_zero_ps_most['search term'].unique():
    print(f"search term: {term}")
    zero_ps_combos = []
    for i in range(1, 5):  # Iterate through ps columns
        ps_col = f'ps {i}'
        combo_col = f'combo {i}'
        # Filter rows where ps is 0 and add corresponding combo to the list
        zero_ps_combos.extend(rows_with_zero_ps_most[(rows_with_zero_ps_most['search term'] == term) & 
                                                     (rows_with_zero_ps_most[ps_col] == 0)][combo_col])
    # Display unique combos with ps equal to 0 for the search term
    print(f"combos with ps equal to zero: {set(zero_ps_combos)}")
    print()
# Out:
# Most relevant preference tests
#
# search term: long covid
# combos with ps equal to zero: {'c3', 'c5', 'c1'}
#
# search term: asthma
# combos with ps equal to zero: {'c7', 'c2'}
#
# search term: naegleria fowleri infection
# combos with ps equal to zero: {'c14', 'c10'}
#
# search term: zika microcephaly
# combos with ps equal to zero: {'c5', 'c4'}
#
# search term: sublingual immunotherapy
# combos with ps equal to zero: {'c8', 'c3', 'c7', 'c2'}
#
# search term: AIDS
# combos with ps equal to zero: {'c3', 'c5'}
#
# search term: t-cell function
# combos with ps equal to zero: {'c9', 'c5', 'c2', 'c10'}
#
# search term: addison's disease
# combos with ps equal to zero: {'c3', 'c10', 'c5', 'c4'}
#
# search term: cancer
# combos with ps equal to zero: {'c8', 'c3', 'c5'}
#
# search term: myocardial infarction
# combos with ps equal to zero: {'c7', 'c2'}
#
# search term: dendritic cells
# combos with ps equal to zero: {'c8', 'c7', 'c2'}
#
# search term: mast cells
# combos with ps equal to zero: {'c8', 'c3', 'c7', 'c4'}
#
# search term: rational cancer drug design
# combos with ps equal to zero: {'c5', 'c10', 'c2'}
#
# search term: metabolomics
# combos with ps equal to zero: {'c3', 'c10', 'c4'}
#
# search term: pinealocyte
# combos with ps equal to zero: {'c4'}
#
# search term: plasmacytoid dendritic cells
# combos with ps equal to zero: {'c3', 'c5', 'c6', 'c1'}
#
# search term: gwas
# combos with ps equal to zero: {'c8', 'c7', 'c6', 'c1'}
#
# search term: mycobacterium
# combos with ps equal to zero: {'c3', 'c5', 'c4'}
#
# search term: tuberculin skin test
# combos with ps equal to zero: {'c3'}
#
# search term: hiv
# combos with ps equal to zero: {'c6', 'c2', 'c4'}
#
# search term: influenza
# combos with ps equal to zero: {'c4', 'c2', 'c9', 'c5', 'c7'}
#
# search term: allergy treatment
# combos with ps equal to zero: {'c7'}
#
# search term: allergen skin prick test
# combos with ps equal to zero: {'c11'}
